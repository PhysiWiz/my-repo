# %% [markdown]
# # Tutorial

# %% [markdown]
# ## Excercise 1: Python as a Calculator
# Let us introduce the following constants
#
# <center>
#
# $h \approx 6.62607015 \times 10^{-34}$ J/Hz
#
# $c = 299792458$ m/s
#
# $\pi \approx 3.14159265$
#
# $\hbar = \frac{h}{2\pi}$
#
# $e \approx 1.60217663 \times 10^{-19} $ C
#
# $m_e \approx 9.10938370 \times 10^{-31}$ kg
#
# $\varepsilon_0 \approx 8.85418781\times 10^{-12}$ F/m
#
# </center>
#
# <img src="images/calculator.png" alt="two dice" width="200"/>
#
# Save them in python as variables

# %%
h = 6.62607015e-34
c = 299792458
pi = 3.14159265
hbar = h / (2*pi)
e = 1.60217663e-19
me = 9.10938370e-31
ep0 = 8.85418781e-12

# %% [markdown]
# Put them in a data structure.
#
# *Think about what might be best...*

# %%
constants = {'h': h, 'c': c, 'pi' : pi, 'hbar' : hbar, 'e' : e, 'me' : me, 'ep0' : ep0}

# %% [markdown]
# Check that this in fact works.

# %%
constants['hbar']
# Out:
# 1.0545718188511804e-34

# %% [markdown]
# Use these to calculate the fine structure constant,
# $$\alpha = \frac{1}{4 \pi \varepsilon_0} \frac{e^2}{\hbar c}$$

# %%
alpha = constants['e']**2 / (4 * constants['pi'] * constants['ep0'] * constants['hbar'] * constants['c'])
print(alpha)
# Out:
# 0.007297352535148513

# %% [markdown]
# ## Exercise 2: Nested Lists and Matrices
#
# Take the matrix
#
# $$A = \begin{bmatrix}
# 3.14 & 42 \\ 2.71&11
# \end{bmatrix}$$
#
# Using nested lists as a matrix representation, find and print it's determinant, then find and print it's inverse.

# %%
A = [[3.14,42],[2.71,11]]
det = 0
for i in range(len(A)):
    det += A[0][i] * (-1)**i * A[1][i-1 % len(A)] 
print(det)

inverse_A = A.copy()
inverse_A[0][0], inverse_A[1][1] = (1/det) * inverse_A[1][1], (1/det) * inverse_A[0][0]
inverse_A[0][1], inverse_A[1][0] = -(1/det) * inverse_A[0][1], -(1/det) * inverse_A[1][0]
print(inverse_A)
# Out:
# -79.28
# [[-0.13874873864783047, 0.5297679112008072], [0.03418264379414732, -0.03960645812310797]]

# %% [markdown]
# ## Exercise 3: What is True and/or False?
# Discuss and think about the following statements and see if you can predict what will happen.
#
# First we will start with casting numbers to Boolean values.
# - ``` bool(0) ```
# - ``` bool(1) ```
# - ``` bool(0.0) ```
# - ``` bool(1.0) ```
# - ``` bool(24) ```
# - ``` bool(-76.2) ```

# %% [markdown]
# 0 I think will give False and 1 defintiely will give True. For the other values, I assume they will also give True because they are not 0 so the only value then would be True

# %%
print(bool(0))
print(bool(1))
print(bool(0.0))
print(bool(1.0))
print(bool(24))
print(bool(-76.2))
# Out:
# False
# True
# False
# True
# True
# True

# %% [markdown]
# We can do the same thing with strings.
# - ``` bool('') ```
# - ``` bool('hello') ```

# %% [markdown]
# I think the first one will be False, like a null array and then the hello would be True because it is not null and has a value.

# %%
print(bool(''))
print(bool('hello'))
# Out:
# False
# True

# %% [markdown]
# We can cast data structures into Boolean.
# - ``` bool([]) ```
# - ``` bool({}) ```
# - ``` bool() ```
# - ``` bool((1)) ```
# - ``` bool([5,6,1]) ```
# - ``` bool({'hello',2.5,9}) ```
# - ``` bool({}) ```

# %% [markdown]
# all the empty data structures should give False, the bool() one too and then the other ones will just have True as they have values in them that aren't a null or 0

# %%
print(bool([]))
print(bool({}))
print(bool(()))
print(bool((1)))
print(bool([5,6,1]))
print(bool({'hello',2.5,9}))
print(bool({}))
# Out:
# False
# False
# False
# True
# True
# True
# False

# %% [markdown]
# Can we cast `None`?
# - ``` bool(None) ```

# %% [markdown]
# I think bool(None) will give False because like with bool() because there's just no data

# %%
print(bool(None))
# Out:
# False

# %% [markdown]
# When we use `not` it casts the proceeding value into boolean.
# - ``` not True ```
# - ``` not False ```
# - ``` not 1 ```
# - ``` not 0.0 ```
# - ``` not 72 ```
# - ``` not -17.3 ```
# - ``` not '' ```
# - ``` not "hi" ```
# - ``` not () ```
# - ``` not None ```

# %% [markdown]
# What would be an empty data structure, 0 or None I think would be True with the not and then for any of the values with a value in it that is not 0 will give False for the vice versa reason

# %%
print(bool(not True))
print(bool(not False))
print(bool(not 1))
print(bool(not 0.0))
print(bool(not 72))
print(bool(not -17.3))
print(bool(not ""))
print(bool(not "hi"))
print(bool(not ()))
print(bool(not None))
# Out:
# False
# True
# False
# True
# False
# False
# True
# False
# True
# True

# %% [markdown]
# And we can use two `not`s
# - ```not not True```
# - ```not not False```
# - ```not not {2,4}```

# %% [markdown]
# The double cancel out so True will be True, False False and {2,4} will be True

# %%
print(bool(not not True))
print(bool(not not False))
print(bool(not not {2,4}))
# Out:
# True
# False
# True

# %% [markdown]
# We will move on and look at `and`.
# - ```True and True```
# - ```True and False```
# - ```False and True```
# - ```False and False```

# %% [markdown]
# First one will be True, second False, third False and final False

# %%
print(bool(True and True))
print(bool(True and False))
print(bool(False and True))
print(bool(False and False))
# Out:
# True
# False
# False
# False

# %% [markdown]
# But what happens when we using things that aren't Boolean?
# - ```False and 'hello'```
# - ```'hello' and False```
# - ```'hello' and True```
# - ```True and 'hello'```

# %% [markdown]
# I think the strings will a True rating so top is False, then False then True then True

# %%
print(bool(False and 'hello'))
print(bool('hello' and False))
print(bool('hello' and True))
print(bool(True and 'hello'))
# Out:
# False
# False
# True
# True

# %% [markdown]
# That's a little strange... Lets see what else we can do!
# - ```None and {}```
# - ```'' and True```
# - ```25 and {25}```
# - ```{0} and 0```

# %% [markdown]
# Top is empty and empty so False, second will be False as it is empty (False) and True then True for the 3rd and False for last

# %%
print(bool(None and {}))
print(bool('' and True))
print(bool(25 and {25}))
print(bool({0} and 0))
# Out:
# False
# False
# True
# False

# %% [markdown]
# Lets try with `or`.
# - ```None or {}```
# - ```'' or True```
# - ```25 or {25}```
# - ```{0} or 0```

# %% [markdown]
# Top is empty or empty so False, then empty or True so True then value or value not 0 so True and then filled array or 0 so True

# %%
print(bool(None or {}))
print(bool('' or True))
print(bool(25 or {25}))
print(bool({0} or 0))
# Out:
# False
# True
# True
# True

# %% [markdown]
# Finally, we can also play with operator presidence.
# - ```not (True or False) or 'hello'```
# - ```'first' and 'second' or False```
# - ```False or not None and 1+0*2-1```
# - ```(0) or not 0```
# - ```(0,) or not 0```

# %% [markdown]
# First is True or filled so True second, the and is True and then with the or it is overall True, third, we have the or with the not wich gives True then the math is 0 so the and gives False. Fourth is filled array or True so True overall and the last one is filled array or True so True

# %%
print(bool(not (True or False) or 'hello'))
print(bool('first' and 'second' or False))
print(bool(False or not None and 1+0*2-1))
print(bool((0) or not 0))
print(bool((0,) or not 0))
# Out:
# True
# True
# False
# True
# True

# %% [markdown]
# ## Exercise 4: Periodic Function
# Observe the following function, used in the famous Shor's algorithm.
#
# <center>
#
# $f(x) = a^x mod N$
#
# </center>
#
# This function is periodic, with $r$ being the smallest(non-zero) integer such that
#
# <center>
#
# $a^r mod N = 1$
#
# </center>
#
# Let $a=2$ and $N=31$.
#
# Create a list that contains the values of this function for $x=0,1,...,10$.
#
#
# <img src="images/Shors_algorithm.png" alt="two dice" width="700"/>

# %%
List = [] #Creating an empty list

List.append((2**0)%31)
List.append((2**1)%31)
List.append((2**2)%31)
List.append((2**3)%31)
List.append((2**4)%31)
List.append((2**5)%31)
List.append((2**6)%31)
List.append((2**7)%31)
List.append((2**8)%31)
List.append((2**9)%31)
List.append((2**10)%31)

print(List)
# Out:
# [1, 2, 4, 8, 16, 1, 2, 4, 8, 16, 1]

# %% [markdown]
# Using this list or otherwise, observe and print the value of r.

# %%
r = 5
print(r)
# Out:
# 5

# %% [markdown]
# Now convert this list to a set and print it to observe the values taken by the function in a single period.

# %%
print(set(List))
# Out:
# {1, 2, 4, 8, 16}
